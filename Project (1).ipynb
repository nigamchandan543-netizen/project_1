# %%
print(" welcome to the interactive personal data collector !")
print("          ")
name=str(input("please enter your name :"))
age=int(input("please enter youre age :" ))
height=float(input("please enter your height :"))
fav_num=float(input("please enter your favourite number :"))
print("          ")
print("Thank you! Here is the information we collected:")
print("          ")
print("name:",name,type(name),"memory address:",id(name))
print("age:",age,type(age),"memory address:",id(age))
print("Height:",height,type(height),"memory address:",id(height))
print("favourite number:",fav_num,type(fav_num),"memory address:",id(fav_num))
print("          ")
print("Your birth year is approximately:",2026-age,"(based on your age of" ,age,")")
print("          ")
print("Thank you for using the Personal Data Collector. Goodbye!")
# Out:
#  welcome to the interactive personal data collector !
# please enter your name : chandan
# please enter youre age : 22
# please enter your height : 1.71
# please enter your favourite number : 3.14
#
# Thank you! Here is the information we collected:
#
# name: chandan <class 'str'> memory address: 2477138284384
# age: 22 <class 'int'> memory address: 140724238132808
# Height: 1.71 <class 'float'> memory address: 2477146380240
# favourite number: 3.14 <class 'float'> memory address: 2477146385936
#
# Your birth year is approximately: 2004 (based on your age of 22 )
#
# Thank you for using the Personal Data Collector. Goodbye!
